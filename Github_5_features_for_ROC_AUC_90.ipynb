# %% [markdown]
# **Исследовательский анализ данных (EDA)**

# %%
df_join
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  target
# 0          0.43      -4.11       1.25       4.84       7.61       1
# 1         -0.22       3.83     -10.05      -1.11       1.99       0
# 2          8.57      -2.50       5.40      -6.22       6.95       1
# 3          7.67      -4.23       8.14       3.75       3.46       0
# 4          3.55      -2.59      -2.10       7.99      -3.52       1
# ...         ...        ...        ...        ...        ...     ...
# 2995     -10.51       1.45      -0.14       0.92       2.75       0
# 2996      -9.80      -5.09       1.04       4.37       5.18       0
# 2997      -6.33      -0.32       7.34      -4.11       5.75       1
# 2998      -1.52      -3.70       9.36      -0.91       4.07       0
# 2999      11.10       3.46      -1.37      -2.29      -1.28       1
#
# [3000 rows x 6 columns]

# %%
df_join.info()# общая информация о типах данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  3000 non-null   float64
#  1   feature_2  3000 non-null   float64
#  2   feature_3  3000 non-null   float64
#  3   feature_4  3000 non-null   float64
#  4   feature_5  3000 non-null   float64
#  5   target     3000 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 140.8 KB

# %%
# проверка на пропуски, абсолютные дубликаты и уникальные значения
# Out:
# <style type="text/css">
# #T_6e69c_row0_col0, #T_6e69c_row0_col2, #T_6e69c_row1_col0, #T_6e69c_row1_col2, #T_6e69c_row2_col0, #T_6e69c_row2_col2, #T_6e69c_row3_col0, #T_6e69c_row3_col2, #T_6e69c_row4_col0, #T_6e69c_row4_col2, #T_6e69c_row5_col0, #T_6e69c_row5_col1, #T_6e69c_row5_col2 {
#   background-color: #def5e5;
#   color: #000000;
# }
# #T_6e69c_row0_col1, #T_6e69c_row1_col1, #T_6e69c_row2_col1, #T_6e69c_row3_col1, #T_6e69c_row4_col1 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e69c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e69c_level0_col0" class="col_heading level0 col0" >Missing value</th>
#       <th id="T_6e69c_level0_col1" class="col_heading level0 col1" >N unique value</th>
#       <th id="T_6e69c_level0_col2" class="col_heading level0 col2" >N duplicated value</th>
#       <th id="T_6e69c_level0_col3" class="col_heading level0 col3" >dtype</th>
#     </tr>
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Статистика
# Out:
#         Name  Skew  Kurtosis   Var  Std  Mean
# 0  feature_1  0.05     -0.76 29.52 5.43  0.14
# 1  feature_2 -0.02     -0.72 29.05 5.39  0.04
# 2  feature_3  0.03     -0.70 29.40 5.42  0.02
# 3  feature_4 -0.01     -0.71 28.52 5.34  0.02
# 4  feature_5 -0.02     -0.75 29.53 5.43  0.03

# %%
# Статистика
# Out:
#         Name              Тест bartlett        Тест Левена median  \
# 0  feature_1  (10319.935044179998, 0.0)  (5452.082479165039, 0.0)
# 1  feature_2  (10272.470218363518, 0.0)  (5366.923359943189, 0.0)
# 2  feature_3  (10308.495217124668, 0.0)  (5403.613612160535, 0.0)
# 3  feature_4  (10218.678738770075, 0.0)  (5474.216295146567, 0.0)
# 4  feature_5   (10321.46640395575, 0.0)  (5499.873607933516, 0.0)
#
#            Тест Левена mean
# 0  (5377.143208384873, 0.0)
# 1  (5291.965200501806, 0.0)
# 2  (5328.354575316691, 0.0)
# 3  (5401.504047281703, 0.0)
# 4  (5423.354314418833, 0.0)

# %%
# Критерий К-квадрата Д'Агостино : проверяет, отличается ли выборка от нормального распределения,вычисляет сводную статистику по данным, а именно эксцесс и асимметрию,
#чтобы определить, отклоняется ли распределение данных от нормального распределения
# Out:
# feature_1                              p-val=0.000
# feature_2                              p-val=0.000
# feature_3                              p-val=0.000
# feature_4                              p-val=0.000
# feature_5                              p-val=0.000
# target                                 p-val=0.000
# ****************************************
# .: Критерий К-квадрата ДАгостино :.
# ****************************************
#
# Вероятно, что нормальное распределение значений имеют признаки:
#
#
# Возможно, что распределение значений не соответсвует нормальному в признаках:
#
# feature_1
# feature_2
# feature_3
# feature_4
# feature_5
# target

# %%
#Тест Шапиро-Уилка — это тест на нормальность частотной статистики .
#Тест Шапиро-Вилка оценивает выборку данных и дает количественную оценку вероятности того, что данные были получены из гауссовского распределения.
# Out:
# Statistics=0.988, p1=0.000
# Statistics=0.990, p1=0.000
# Statistics=0.991, p1=0.000
# Statistics=0.991, p1=0.000
# Statistics=0.989, p1=0.000
# Statistics=0.622, p1=0.000
# **************************
# .: Тест Шапиро-Уилка :.
# **************************
#
# Вероятно, что нормальное распределение значений имеют признаки:
#
#
# Возможно, что распределение значений не соответсвует нормальному в признаках:
#
# feature_1
# feature_2
# feature_3
# feature_4
# feature_5
# target

# %%
# Вычисляем коэффициенты ранговой корреляции Кендалла
# Out:
# <style type="text/css">
# #T_32550_row0_col0, #T_32550_row1_col1, #T_32550_row2_col2, #T_32550_row3_col3, #T_32550_row4_col4, #T_32550_row5_col5 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_32550_row0_col1, #T_32550_row1_col0, #T_32550_row2_col1, #T_32550_row2_col4, #T_32550_row4_col0 {
#   background-color: #d8f2e0;
#   color: #000000;
# }
# #T_32550_row0_col2, #T_32550_row5_col2 {
#   background-color: #dcf4e3;
#   color: #000000;
# }
# #T_32550_row0_col3, #T_32550_row1_col2, #T_32550_row1_col4, #T_32550_row1_col5, #T_32550_row3_col0, #T_32550_row3_col2, #T_32550_row4_col1, #T_32550_row4_col2 {
#   background-color: #def5e5;
#   color: #000000;
# }
# #T_32550_row0_col4, #T_32550_row2_col5, #T_32550_row5_col1 {
#   background-color: #daf3e1;
#   color: #000000;
# }
# #T_32550_row0_col5, #T_32550_row3_col4, #T_32550_row4_col3 {
#   background-color: #d2f0db;
#   color: #000000;
# }
# #T_32550_row1_col3, #T_32550_row2_col0, #T_32550_row3_col1 {
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Вычисляем коэффициенты корреляции Пирсона
# Out:
# <style type="text/css">
# #T_70852_row0_col0, #T_70852_row1_col1, #T_70852_row2_col2, #T_70852_row3_col3, #T_70852_row4_col4, #T_70852_row5_col5 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_70852_row0_col1, #T_70852_row0_col4, #T_70852_row2_col1, #T_70852_row2_col4 {
#   background-color: #fcf6b8;
#   color: #000000;
# }
# #T_70852_row0_col2 {
#   background-color: #fcfbbd;
#   color: #000000;
# }
# #T_70852_row0_col3, #T_70852_row1_col2, #T_70852_row1_col4, #T_70852_row1_col5, #T_70852_row3_col0, #T_70852_row3_col2, #T_70852_row4_col1, #T_70852_row4_col2 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_70852_row0_col5, #T_70852_row1_col3 {
#   background-color: #fceeb0;
#   color: #000000;
# }
# #T_70852_row1_col0, #T_70852_row4_col0 {
#   background-color: #fcf4b6;
#   color: #000000;
# }
# #T_70852_row2_col0, #T_70852_row3_col1 {
#   background-color: #fcf0b2;
#   color: #000000;
# }
# #T_70852_row2_col3, #T_70852_row4_col5 {
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Вычисляем коэффициенты ранговой корреляции Спирмана
# Out:
# <style type="text/css">
# #T_515e6_row0_col0, #T_515e6_row1_col1, #T_515e6_row2_col2, #T_515e6_row3_col3, #T_515e6_row4_col4, #T_515e6_row5_col5 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_515e6_row0_col1, #T_515e6_row0_col4, #T_515e6_row2_col4, #T_515e6_row4_col0 {
#   background-color: #002554;
#   color: #f1f1f1;
# }
# #T_515e6_row0_col2, #T_515e6_row2_col5, #T_515e6_row5_col1 {
#   background-color: #002553;
#   color: #f1f1f1;
# }
# #T_515e6_row0_col3, #T_515e6_row1_col2, #T_515e6_row1_col4, #T_515e6_row1_col5, #T_515e6_row3_col0, #T_515e6_row4_col1, #T_515e6_row4_col2 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_515e6_row0_col5 {
#   background-color: #002859;
#   color: #f1f1f1;
# }
# #T_515e6_row1_col0, #T_515e6_row2_col1 {
#   background-color: #002656;
#   color: #f1f1f1;
# }
# #T_515e6_row1_col3, #T_515e6_row3_col4, #T_515e6_row3_col5, #T_515e6_row5_col4 {
#   background-color: #00295d;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Корреляционная карта (Тепловая карта)
# Out:
# <Axes: >

# %%
# гистограммы распределения

# %%
sns.barplot(x = 'target', y = 'feature_1', data = df_join, ci = None)
# Out:
# Text(0, 0.5, 'feature_1')

# %%
sns.catplot(x = 'target', y = 'feature_1',kind="swarm", data=df_join)

# %%
sns.barplot(x = 'target', y = 'feature_2', data = df_join, ci = None)
# Out:
# Text(0, 0.5, 'feature_2')

# %%
sns.catplot(x = 'target', y = 'feature_2',kind="swarm", data=df_join)

# %%
sns.barplot(x = 'target', y = 'feature_3', data = df_join, ci = None))
# Out:
# Text(0, 0.5, 'feature_3')

# %%
sns.catplot(x = 'target', y = 'feature_3',kind="swarm", data=df_join)

# %%
sns.barplot(x = 'target', y = 'feature_4', data = df_join, ci = None)
# Out:
# Text(0, 0.5, 'feature_4')

# %%
sns.catplot(x = 'target', y = 'feature_4',kind="swarm", data=df_join)

# %%
sns.barplot(x = 'target', y = 'feature_5', data = df_join, ci = None)
# Out:
# Text(0, 0.5, 'feature_5')

# %%
sns.catplot(x = 'target', y = 'feature_5',kind="swarm", data=df_join)

# %%
sns.countplot(x="target", data=df_join)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
#Анализ выбросов
# Out:
# <Axes: ylabel='target'>

# %%
#Графики распределения

# %% [markdown]
# **ROC AUC train: 1.0, test: 0.954**

# %%
# Out:
# <Axes: >

# %%
# Модель 1
print('\033[91m\033[1m'+'.: Classification report train :.'+'\033[0m')
print(classification_report(y_train, pred_train_abc))
print('\033[91m\033[1m'+'.: Classification report test :.'+'\033[0m')
print(classification_report(y_test, pred_test_abc))
# Out:
# Усредненная правильность и стандартное отклонение cv train: 0.944+-0.008
# ********************************
# Усредненная оценка AUC-ROC и стандартное отклонение cv train: 0.979+-0.007
# ********************************
# Усредненная оценка AUC-ROC c поправкой
# на стандартное отклонение cv train: 0.972
# ********************************
# Усредненная правильность и стандартное отклонение cv test: 0.702+-0.065
# ********************************
# Усредненная оценка AUC-ROC и стандартное отклонение cv test: 0.744+-0.067
# ********************************
# Усредненная оценка AUC-ROC c поправкой
# на стандартное отклонение cv test: 0.677
# accuracy_train: 1.000
# accuracy_test: 0.955
# ********************************
# roc_auc_train: 1.000
# roc_auc_test: 0.954
# ********************************
# ********************************
# .: Classification report train :.
# ********************************
#               precision    recall  f1-score   support
#
# ...

# %%
# Модель 2
print('\033[91m\033[1m'+'.: Classification report train :.'+'\033[0m')
print(classification_report(y_train, pred_train_abc))
print('\033[91m\033[1m'+'.: Classification report test :.'+'\033[0m')
print(classification_report(y_test, pred_test_abc))
# Out:
# Усредненная правильность и стандартное отклонение cv train: 0.934+-0.011
# ********************************
# Усредненная оценка AUC-ROC и стандартное отклонение cv train: 0.985+-0.004
# ********************************
# Усредненная оценка AUC-ROC c поправкой
# на стандартное отклонение cv train: 0.982
# ********************************
# Усредненная правильность и стандартное отклонение cv test: 0.695+-0.069
# ********************************
# Усредненная оценка AUC-ROC и стандартное отклонение cv test: 0.766+-0.070
# ********************************
# Усредненная оценка AUC-ROC c поправкой
# на стандартное отклонение cv test: 0.697
# accuracy_train: 1.000
# accuracy_test: 0.930
# ********************************
# roc_auc_train: 1.000
# roc_auc_test: 0.929
# ********************************
# ********************************
# .: Classification report train :.
# ********************************
#               precision    recall  f1-score   support
#
# ...

# %%
#Матрица ошибок

# %%
# Предсказание модели
# Out:
#       predicted target  target  error
# 1782                 0       0      0
# 3917                 0       0      0
# 221                  0       0      0
# 2135                 1       1      0
# 5224                 1       1      0
# ...                ...     ...    ...
# 5591                 1       1      0
# 5710                 1       1      0
# 5176                 1       1      0
# 1647                 0       0      0
# 3414                 0       0      0
#
# [600 rows x 3 columns]

# %%
# Ошибки прогноза
# Out:
# predicted target  target  error
# 0                 0        0       299
# 1                 1        0       259
# 0                 1        1        27
# 1                 0       -1        15
# dtype: int64

# %%
print('\033[91m\033[1m'+'.: Ошибки прогноза:.'+'\033[0m')
# Out:
# *******************************************
# .: Ошибки прогноза:.
# *******************************************
# predicted target  target  error
# 0                 1       1        27
# dtype: int64
# количество ошибок: 27
# predicted target  target  error
# 1                 0       -1       15
# dtype: int64
# количество ошибок: -15
